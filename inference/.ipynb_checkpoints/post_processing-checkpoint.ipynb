# %%
import torch
import numpy as np
import cv2
import copy
import os
import imageio.v2 as imageio
import matplotlib.pyplot as plt
import csv
from pathlib import Path
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from scipy.stats import chi2_contingency
plt.rcParams['font.family'] = ['serif']
plt.rcParams['font.serif'] = ['Times New Roman']

# %%
project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
sys.path.append(project_root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
#       2 sys.path.append(project_root)
#
# NameError: name '__file__' is not defined

# %%
model_name="MatSegNet"

# %%
base_directory=Path('C:/Users/xiaoh/Desktop/3rd-Paper/Segmentation_Pipeline')

images_saved_dir=os.path.join(base_directory,'outputs','MatSegNet_qualitative_results',"Carbide_orientations") 
bainite = os.path.join(base_directory,'outputs','MatSegNet_qualitative_results','Predictions','bainite') 
martensite =os.path.join(base_directory,'outputs','MatSegNet_qualitative_results','Predictions','martensite')  

bainite_list = [os.path.join(bainite,i) for i in os.listdir(bainite)]
martensite_list = [os.path.join(martensite,i) for i in os.listdir(martensite)]

print(f'there are {len(bainite_list)} bainite images, and {len(martensite_list)} martensite images')
# Out:
# there are 1304 bainite images, and 261 martensite images

# %%
def highlight_carbides(image_path, output_dir, number=0, name='Name', ratio=2):
    """
    Analyzes an image to identify carbides, highlights them with bounding boxes,
    and generates a histogram of their angular distribution.

    Args:
        image_path (str): The full path to the input image file.
        output_dir (str): The directory where output images will be saved.
        number (int, optional): An identifier number for the output files. Defaults to 0.
        name (str, optional): A name identifier for the output files. Defaults to 'Name'.
        ratio (float, optional): The aspect ratio for the histogram plot. Defaults to 2.

    Returns:
        float: The percentage of carbides found in the most frequent orientation bin.
               Returns 0.0 if no carbides are found. Returns None on file read error.
    """
  
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
    comparison_highlighted_dir=os.path.join(output_dir,"Merged Highlighted Carbides")
    orientation_histogram_dir=os.path.join(output_dir,"Carbide Orientation")
    highlighted_dir=os.path.join(output_dir,"Carbide Highlighted")
    
    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(comparison_highlighted_dir, exist_ok=True)
    os.makedirs(orientation_histogram_dir, exist_ok=True)
    os.makedirs(highlighted_dir, exist_ok=True)
    
    # 2. Read the source image and handle potential errors
    img_raw = cv2.imread(image_path)
    if img_raw is None:
        print(f"Error: File not found or could not be opened at path: {image_path}")
        return None

    # 3. Create a copy for drawing and convert to grayscale
    img_with_boxes = copy.deepcopy(img_raw)
    gray = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2GRAY)

    # 4. Binarize the image and find contours
    _, bw = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(bw, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
    
    angle_list = []
    for c in contours:
        # Filter out very small or very large contours
        area = cv2.contourArea(c)
        if not (30 < area < 100000):
            continue
        
        # Get the minimum area rotated rectangle
        rect = cv2.minAreaRect(c)
        box = cv2.boxPoints(rect)
        box = box.astype(int)

        # Normalize the angle to be the orientation of the longer side
        width, height = rect[1]
        angle = rect[2]

        if width < height:
            angle = 90 - angle
        else:
            angle = -angle
            
        angle_list.append(angle)
        cv2.drawContours(img_with_boxes, [box], 0, (80, 127, 255), 2)

    # 5. Save a side-by-side comparison image
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
    axs[0].imshow(cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB))
    axs[0].set_title('Original Image', fontsize=20)
    axs[0].axis('off')
    
    axs[1].imshow(cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB))
    axs[1].set_title('Carbide Orientation Highlighted', fontsize=20)
    axs[1].axis('off')

    comparison_filename = f"{name}_{number}_comparison.jpg"
    plt.savefig(os.path.join(comparison_highlighted_dir, comparison_filename), dpi=100, bbox_inches='tight')
    plt.close(fig)

    # 6. Save the final image with highlighted carbides
    highlighted_filename = f"{name}_{number}_highlighted.jpg"
    cv2.imwrite(os.path.join(highlighted_dir  , highlighted_filename), img_with_boxes)

    # 7. Handle the case where no valid carbides were found
    if not angle_list:
        print(f"Warning: No valid carbides found in image {name}_{number}.")
        return 0.0

    # 8. Create and save the angle distribution histogram if carbides were found
    fig, ax = plt.subplots(figsize=(16, 9))
    counts, bins, patches = ax.hist(angle_list, color='blue', alpha=0.7, bins=18, range=(-90, 90), edgecolor='black', linewidth=2)
    
    # Add count labels above each bar
    for rect_patch in patches:
        height = rect_patch.get_height()
        if height > 0:
            ax.annotate(f'{int(height)}', 
                        xy=(rect_patch.get_x() + rect_patch.get_width() / 2, height),
                        xytext=(0, 5), textcoords='offset points', ha='center', va='bottom')
    
    ax.set_aspect(ratio)
    ax.set_title('Carbide Angle Distribution', fontsize=20)
    ax.set_xlim(-100, 100)
    ax.set_xlabel('Angle (°)', fontsize=20)
    ax.set_ylabel('Number of Carbides', fontsize=20)
    ax.set_xticks(np.arange(-90, 91, 10))
    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2)
    ax.tick_params(axis='both', which='major', labelsize=10, direction='in', length=4)
    
    histogram_filename = f"{name}_{number}_histogram.jpg"
    plt.savefig(os.path.join(orientation_histogram_dir, histogram_filename), dpi=100)
    plt.close(fig)

    # 9. Calculate the percentage of the most frequent angle
    max_count = np.max(counts)
    total_count = np.sum(counts)
    angle_percentage = max_count / total_count if total_count > 0 else 0.0

    return angle_percentage

# %%
pwd
# Out:
# 'C:\\Users\\xiaoh\\Desktop\\3rd-Paper\\Segmentation_Pipeline\\inference'

# %%
def get_percentage_list(dataset ,images_saved_dirname,name='Name'):
    output_list = []
    for i, image_path in enumerate(dataset):
        print('Processing image {}: {}'.format(i, image_path))
        percentage = highlight_carbides(image_path, images_saved_dir,number=i, name=name)
        if percentage is not None:
            output_list.append(percentage)
        else:
            print(f"Skipping image {i} ({image_path}) due to an error.")

    return output_list

# %%
bainite_k_list=get_percentage_list(bainite_list,images_saved_dir,name="Lower_Bainite")
martensite_k_list=get_percentage_list(martensite_list,images_saved_dir,name="Tempered_Martensite")
# Out:
# Processing image 0: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_0.png
# Processing image 1: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_1.png
# Processing image 2: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_10.png
# Processing image 3: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_11.png
# Processing image 4: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_12.png
# Processing image 5: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_13.png
# Processing image 6: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_14.png
# Processing image 7: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_15.png
# Processing image 8: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_2.png
# Processing image 9: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_3.png
# Processing image 10: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_4.png
# Processing image 11: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_5.png
# Processing image 12: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_6.png
# Processing image 13: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_7.png
# Processing image 14: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_8.png
# Processing image 15: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_0_9.png
# Processing image 16: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_0.png
# Processing image 17: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_1.png
# Processing image 18: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_10.png
# Processing image 19: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_11.png
# Processing image 20: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_12.png
# Processing image 21: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_13.png
# Processing image 22: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_14.png
# Processing image 23: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_15.png
# Processing image 24: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_2.png
# Processing image 25: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_3.png
# Processing image 26: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_4.png
# Processing image 27: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_5.png
# Processing image 28: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_6.png
# Processing image 29: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_7.png
# Processing image 30: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_8.png
# Processing image 31: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_10_9.png
# Processing image 32: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_0.png
# Processing image 33: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_1.png
# Processing image 34: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_10.png
# Processing image 35: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_11.png
# Processing image 36: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_12.png
# Processing image 37: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_13.png
# Processing image 38: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_14.png
# Processing image 39: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_15.png
# Processing image 40: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_2.png
# Processing image 41: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_3.png
# Processing image 42: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_4.png
# Processing image 43: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_5.png
# Processing image 44: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_6.png
# Processing image 45: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_7.png
# Processing image 46: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_8.png
# Processing image 47: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_11_9.png
# Processing image 48: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_0.png
# Processing image 49: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_1.png
# Processing image 50: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_10.png
# Processing image 51: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_11.png
# Processing image 52: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_12.png
# Processing image 53: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_13.png
# Processing image 54: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_14.png
# Processing image 55: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_15.png
# Processing image 56: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_2.png
# Processing image 57: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_3.png
# Processing image 58: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_4.png
# Processing image 59: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_5.png
# Processing image 60: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_6.png
# Processing image 61: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_7.png
# Processing image 62: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_8.png
# Processing image 63: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_12_9.png
# Processing image 64: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_0.png
# Processing image 65: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_1.png
# Processing image 66: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_10.png
# Processing image 67: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_11.png
# Processing image 68: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_12.png
# Processing image 69: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_13.png
# Processing image 70: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_14.png
# Processing image 71: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_15.png
# Processing image 72: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_2.png
# Processing image 73: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_3.png
# Processing image 74: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_4.png
# Processing image 75: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_5.png
# Processing image 76: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_6.png
# Processing image 77: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_7.png
# Processing image 78: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_8.png
# Processing image 79: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_13_9.png
# Processing image 80: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_0.png
# Processing image 81: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_1.png
# Processing image 82: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_10.png
# Processing image 83: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_11.png
# Processing image 84: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_12.png
# Processing image 85: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_13.png
# Processing image 86: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_14.png
# Processing image 87: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_15.png
# Processing image 88: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_2.png
# Processing image 89: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_3.png
# Processing image 90: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_4.png
# Processing image 91: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_5.png
# Processing image 92: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_6.png
# Processing image 93: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_7.png
# Processing image 94: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_8.png
# Processing image 95: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_1_9.png
# Processing image 96: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_0.png
# Processing image 97: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_1.png
# Processing image 98: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_10.png
# Processing image 99: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_11.png
# Processing image 100: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_12.png
# Processing image 101: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_13.png
# Processing image 102: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_14.png
# Processing image 103: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_15.png
# Processing image 104: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_2.png
# Processing image 105: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_3.png
# Processing image 106: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_4.png
# Processing image 107: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_5.png
# Processing image 108: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_6.png
# Processing image 109: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_7.png
# Processing image 110: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_8.png
# Processing image 111: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_2_9.png
# Processing image 112: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_0.png
# Processing image 113: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_1.png
# Processing image 114: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_10.png
# Processing image 115: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_11.png
# Processing image 116: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_12.png
# Processing image 117: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_13.png
# Processing image 118: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_14.png
# Processing image 119: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_15.png
# Processing image 120: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_2.png
# Processing image 121: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_3.png
# Processing image 122: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_4.png
# Processing image 123: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_5.png
# Processing image 124: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_6.png
# Processing image 125: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_7.png
# Processing image 126: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_8.png
# Processing image 127: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_3_9.png
# Processing image 128: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_0.png
# Processing image 129: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_1.png
# Processing image 130: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_10.png
# Processing image 131: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_11.png
# Processing image 132: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_12.png
# Processing image 133: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_13.png
# Processing image 134: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_14.png
# Processing image 135: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_15.png
# Processing image 136: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_2.png
# Processing image 137: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_3.png
# Processing image 138: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_4.png
# Processing image 139: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_5.png
# Processing image 140: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_6.png
# Processing image 141: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_7.png
# Processing image 142: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_8.png
# Processing image 143: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_4_9.png
# Processing image 144: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_0.png
# Processing image 145: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_1.png
# Processing image 146: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_10.png
# Processing image 147: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_11.png
# Processing image 148: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_12.png
# Processing image 149: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_13.png
# Processing image 150: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_14.png
# Processing image 151: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_15.png
# Processing image 152: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_2.png
# Processing image 153: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_3.png
# Processing image 154: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_4.png
# Processing image 155: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_5.png
# Processing image 156: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_6.png
# Processing image 157: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_7.png
# Processing image 158: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_8.png
# Processing image 159: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_5_9.png
# Processing image 160: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_0.png
# Processing image 161: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_1.png
# Processing image 162: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_10.png
# Processing image 163: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_11.png
# Processing image 164: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_12.png
# Processing image 165: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_13.png
# Processing image 166: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_14.png
# Processing image 167: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_15.png
# Processing image 168: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_2.png
# Processing image 169: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_3.png
# Processing image 170: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_4.png
# Processing image 171: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_5.png
# Processing image 172: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_6.png
# Processing image 173: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_7.png
# Processing image 174: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_8.png
# Processing image 175: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_6_9.png
# Processing image 176: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_0.png
# Processing image 177: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_1.png
# Processing image 178: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_10.png
# Processing image 179: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_11.png
# Processing image 180: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_12.png
# Processing image 181: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_13.png
# Processing image 182: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_14.png
# Processing image 183: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_15.png
# Processing image 184: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_2.png
# Processing image 185: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_3.png
# Processing image 186: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_4.png
# Processing image 187: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_5.png
# Processing image 188: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_6.png
# Processing image 189: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_7.png
# Processing image 190: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_8.png
# Processing image 191: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_7_9.png
# Processing image 192: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_0.png
# Processing image 193: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_1.png
# Processing image 194: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_10.png
# Processing image 195: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_11.png
# Processing image 196: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_12.png
# Processing image 197: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_13.png
# Processing image 198: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_14.png
# Processing image 199: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_15.png
# Processing image 200: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_2.png
# Processing image 201: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_3.png
# Processing image 202: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_4.png
# Processing image 203: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_5.png
# Processing image 204: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_6.png
# Processing image 205: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_7.png
# Processing image 206: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_8.png
# Processing image 207: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_8_9.png
# Processing image 208: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_0.png
# Processing image 209: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_1.png
# Processing image 210: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_10.png
# Processing image 211: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_11.png
# Processing image 212: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_12.png
# Processing image 213: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_13.png
# Processing image 214: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_14.png
# Processing image 215: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_15.png
# Processing image 216: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_2.png
# Processing image 217: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_3.png
# Processing image 218: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_4.png
# Processing image 219: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_5.png
# Processing image 220: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_6.png
# Processing image 221: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_7.png
# Processing image 222: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_8.png
# Processing image 223: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_005_9_9.png
# Processing image 224: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_0.png
# Processing image 225: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_1.png
# Processing image 226: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_10.png
# Processing image 227: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_11.png
# Processing image 228: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_12.png
# Processing image 229: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_13.png
# Processing image 230: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_14.png
# Processing image 231: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_15.png
# Processing image 232: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_2.png
# Processing image 233: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_3.png
# Processing image 234: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_4.png
# Processing image 235: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_5.png
# Processing image 236: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_6.png
# Processing image 237: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_7.png
# Processing image 238: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_8.png
# Processing image 239: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_0_9.png
# Processing image 240: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_0.png
# Processing image 241: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_1.png
# Processing image 242: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_10.png
# Processing image 243: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_11.png
# Processing image 244: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_12.png
# Processing image 245: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_13.png
# Processing image 246: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_14.png
# Processing image 247: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_15.png
# Processing image 248: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_2.png
# Processing image 249: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_3.png
# Processing image 250: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_4.png
# Processing image 251: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_5.png
# Processing image 252: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_6.png
# Processing image 253: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_7.png
# Processing image 254: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_8.png
# Processing image 255: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_10_9.png
# Processing image 256: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_0.png
# Processing image 257: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_1.png
# Processing image 258: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_10.png
# Processing image 259: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_11.png
# Processing image 260: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_12.png
# Processing image 261: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_13.png
# Processing image 262: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_14.png
# Processing image 263: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_15.png
# Processing image 264: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_2.png
# Processing image 265: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_3.png
# Processing image 266: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_4.png
# Processing image 267: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_5.png
# Processing image 268: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_6.png
# Processing image 269: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_7.png
# Processing image 270: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_8.png
# Processing image 271: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_11_9.png
# Processing image 272: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_12_0.png
# Processing image 273: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_12_1.png
# Processing image 274: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_12_10.png
# Processing image 275: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_12_11.png
# Processing image 276: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_12_12.png
# Processing image 277: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\bainite\42CrMo4BAINITE_0.3-2500X_006_12_13.png
# ...
# Processing image 171: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_014_3_3.png
# Processing image 172: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_0_0.png
# Processing image 173: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_0_1.png
# Processing image 174: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_0_2.png
# Processing image 175: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_0_3.png
# Processing image 176: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_1_0.png
# Processing image 177: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_1_1.png
# Processing image 178: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_1_2.png
# Processing image 179: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_1_3.png
# Processing image 180: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_2_0.png
# Processing image 181: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_2_1.png
# Processing image 182: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_2_2.png
# Processing image 183: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_2_3.png
# Processing image 184: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_3_0.png
# Processing image 185: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_3_1.png
# Processing image 186: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_3_2.png
# Processing image 187: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-10000X_020_3_3.png
# Processing image 188: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_0_0.png
# Processing image 189: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_0_1.png
# Processing image 190: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_0_2.png
# Processing image 191: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_1_0.png
# Processing image 192: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_1_1.png
# Processing image 193: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_1_2.png
# Processing image 194: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_2_0.png
# Processing image 195: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_2_1.png
# Processing image 196: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-15000X_013_2_2.png
# Processing image 197: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-20000X_012_0_0.png
# Processing image 198: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-20000X_012_0_1.png
# Processing image 199: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-20000X_012_1_0.png
# Processing image 200: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-20000X_012_1_1.png
# Processing image 201: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_0_0.png
# Processing image 202: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_0_1.png
# Processing image 203: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_0_2.png
# Processing image 204: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_0_3.png
# Processing image 205: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_0_4.png
# Processing image 206: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_0_5.png
# Processing image 207: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_0_6.png
# Processing image 208: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_1_0.png
# Processing image 209: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_1_1.png
# Processing image 210: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_1_2.png
# Processing image 211: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_1_3.png
# Processing image 212: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_1_4.png
# Processing image 213: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_1_5.png
# Processing image 214: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_1_6.png
# Processing image 215: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_2_0.png
# Processing image 216: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_2_1.png
# Processing image 217: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_2_2.png
# Processing image 218: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_2_3.png
# Processing image 219: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_2_4.png
# Processing image 220: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_2_5.png
# Processing image 221: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_2_6.png
# Processing image 222: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_3_0.png
# Processing image 223: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_3_1.png
# Processing image 224: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_3_2.png
# Processing image 225: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_3_3.png
# Processing image 226: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_3_4.png
# Processing image 227: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_3_5.png
# Processing image 228: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_3_6.png
# Processing image 229: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_4_0.png
# Processing image 230: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_4_1.png
# Processing image 231: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_4_2.png
# Processing image 232: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_4_3.png
# Processing image 233: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_4_4.png
# Processing image 234: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_4_5.png
# Processing image 235: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_4_6.png
# Processing image 236: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_5_0.png
# Processing image 237: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_5_1.png
# Processing image 238: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_5_2.png
# Processing image 239: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_5_3.png
# Processing image 240: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_5_4.png
# Processing image 241: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_5_5.png
# Processing image 242: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.48-6000X_016_5_6.png
# Processing image 243: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_0_0.png
# Processing image 244: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_0_1.png
# Processing image 245: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_0_2.png
# Processing image 246: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_1_0.png
# Processing image 247: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_1_1.png
# Processing image 248: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_1_2.png
# Processing image 249: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_2_0.png
# Processing image 250: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_2_1.png
# Processing image 251: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_018_2_2.png
# Processing image 252: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_0_0.png
# Processing image 253: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_0_1.png
# Processing image 254: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_0_2.png
# Processing image 255: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_1_0.png
# Processing image 256: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_1_1.png
# Processing image 257: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_1_2.png
# Processing image 258: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_2_0.png
# Processing image 259: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_2_1.png
# Processing image 260: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\MatSegNet_qualitative_results\Predictions\martensite\N5440MARTENSITE_0.5-15000X_019_2_2.png

# %%
def get_area_percentage(dataset, color_channel=1, threshold=0.9):

    ratio_list = []
    # 使用 enumerate 获取索引和路径，更 Pythonic
    for i, image_path in enumerate(dataset):
        try:
            img = imageio.imread(image_path)

            # 检查图像是否为灰度图或通道数不足
            if len(img.shape) < 3 or img.shape[2] <= color_channel:
                print(f"Warning: Skipping image {i} ({image_path}) because it's grayscale or has too few channels.")
                continue # 跳过这张图片

            # 核心计算逻辑不变
            pixel_count = np.sum(img[:, :, color_channel] / 255 > threshold)
            total_pixels = img.shape[0] * img.shape[1]
            
            ratio = pixel_count / total_pixels if total_pixels > 0 else 0.0
            ratio_list.append(ratio)

        except FileNotFoundError:
            print(f"Error: File not found at {image_path}. Skipping.")
        except Exception as e:
            print(f"An error occurred while processing {image_path}: {e}. Skipping.")
            
    return ratio_list

# %%
bain_area_percentage_list=get_area_percentage(bainite_list)
mar_area_percentage_list=get_area_percentage(martensite_list)

# %% [markdown]
# hypothesis testing, confidence interval estimation, or ANOVA.

# %%
def plot_comparison_scatter(ax, data1, data2, label1, label2, title, ylabel, subplot_label):
    """
    一个辅助函数，用于在给定的坐标轴(ax)上绘制两个数据集的对比散点图。

    参数:
    ax (matplotlib.axes.Axes): 要在其上绘图的子图坐标轴对象。
    data1, data2 (list or np.array): 两个要比较的数据集。
    label1, label2 (str): 两个数据集的标签名称。
    title (str): 子图的标题。
    ylabel (str): Y轴的标签。
    subplot_label (str): 子图的标签，例如 '(a)'。
    """
    # 1. 计算统计数据
    avg1, std1 = np.average(data1), np.std(data1)
    avg2, std2 = np.average(data2), np.std(data2)

    # 2. 绘制数据点和平均值线
    # 为数据点和平均值线添加标签，以便自动生成图例
    ax.scatter(np.arange(len(data1)), data1, facecolors='none', color='red', s=50, label=label1)
    ax.plot([-5, 360], [avg1, avg1], color='red')
    
    ax.scatter(np.arange(len(data2)), data2, facecolors='none', color='blue', marker='^', s=50, label=label2)
    ax.plot([-5, 360], [avg2, avg2], color='blue', linestyle='dashed')

    # 3. 添加统计信息文本框
    stats_text = (
        f"{label1}:\n"
        f"  Average: {avg1:.2f}   STD: {std1:.4f}\n\n"
        f"{label2}:\n"
        f"  Average: {avg2:.2f}   STD: {std2:.4f}"
    )
    # 动态确定文本位置
    ymin, ymax = ax.get_ylim()
    ax.set_ylim(ymin, ymax * 1.2)
    ymin_new, ymax_new = ax.get_ylim()
    text_y_pos = ymin_new + (ymax_new - ymin_new) * 0.95 # 放在顶部
    ax.text(10, text_y_pos, stats_text, fontsize=14, verticalalignment='top')

    # 4. 设置标题和标签
    ax.set_title(title, fontsize=18, pad=10)
    ax.set_xlabel('Image Number', fontsize=16)
    ax.set_ylabel(ylabel, fontsize=16)
   # ax.set_xlim(-5, 360)
    
    # 5. 设置子图标签 (a), (b) ...
    # 使用 ax.transAxes 使其位置相对于坐标轴本身，更稳定
    ax.text(0.02, 0.98, subplot_label, transform=ax.transAxes, fontsize=16,
            fontweight='bold', verticalalignment='top')

    # 6. 美化坐标轴和刻度
    for spine in ax.spines.values():
        spine.set_linewidth(2)
    ax.tick_params(axis='both', which='major', labelsize=15, direction='in', width=2, length=6)

# %%
# 1. 创建图床和子图 (这是创建子图的最佳方式)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# 2. 调用辅助函数绘制第一个子图
plot_comparison_scatter(
    ax=ax1,
    data1=bain_area_percentage_list,
    data2=mar_area_percentage_list,
    label1='Lower Bainite',
    label2='Tempered Martensite',
    title='Carbide Area Percentage Comparison',
    ylabel='Carbide Percentage',
    subplot_label='(a)'
)

# 3. 调用辅助函数绘制第二个子图
plot_comparison_scatter(
    ax=ax2,
    data1=bainite_k_list,
    data2=martensite_k_list,
    label1='Lower Bainite',
    label2='Tempered Martensite',
    title='Carbide Orientation Concentration',
    ylabel='Percentage in Dominant Angle Bin',
    subplot_label='(b)'
)

# 4. 创建一个统一的图例
# 从 ax2 获取所有元素的句柄和标签
handles, labels = ax2.get_legend_handles_labels()
# 在图的右侧居中位置创建一个统一的图例
fig.legend(handles, labels, loc='center right', bbox_to_anchor=(1.08, 0.5), fontsize=15, title="Legend", title_fontsize=16)

# 5. 调整布局并保存
# rect参数为图例留出空间
fig.tight_layout(rect=[0, 0, 0.95, 1])
plt.savefig(f"Orientation_Percentage_Optimized_{model_name}.jpg", dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
import matplotlib.gridspec as gridspec

def plot_comparison_figure(lb_data_a, tm_data_a, lb_data_b, tm_data_b, 
                           ylabel_a='Carbide Percentage', ylabel_b='k', 
                           save_path=None):
    
    # --- 0. 准备工作：字体和辅助函数 ---
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    plt.rcParams['axes.labelweight'] = 'normal'

    def calculate_ci(data, confidence=0.95):
        """计算给定数据的均值的置信区间"""
        n = len(data)
        mean = np.mean(data)
        sem = scipy.stats.sem(data)
        if sem > 0:
            ci_range = scipy.stats.t.interval(confidence, n - 1, loc=mean, scale=sem)
            return mean, ci_range
        else:
            return mean, (mean, mean)

    # --- 1. 计算统计数据和置信区间 ---
    lb_mean_a, lb_ci_a = calculate_ci(lb_data_a)
    tm_mean_a, tm_ci_a = calculate_ci(tm_data_a)
    lb_mean_b, lb_ci_b = calculate_ci(lb_data_b)
    tm_mean_b, tm_ci_b = calculate_ci(tm_data_b)

    # --- 2. 动态计算所有子图的坐标轴范围 ---
    combined_data_a = np.concatenate((lb_data_a, tm_data_a))
    min_a, max_a = combined_data_a.min(), combined_data_a.max()
    range_a = max_a - min_a
    scatter_ylim_a = (min_a - 0.1 * range_a, max_a + 0.3 * range_a)
    hist_xlim_a = (min_a - 0.05 * range_a, max_a + 0.05 * range_a)
    counts_a_lb, _ = np.histogram(lb_data_a, bins=20)
    counts_a_tm, _ = np.histogram(tm_data_a, bins=20)
    max_count_a = max(counts_a_lb.max(), counts_a_tm.max())
    hist_ylim_a = (0, max_count_a * 1.1)

    combined_data_b = np.concatenate((lb_data_b, tm_data_b))
    min_b, max_b = combined_data_b.min(), combined_data_b.max()
    range_b = max_b - min_b
    scatter_ylim_b = (min_b - 0.1 * range_b, max_b + 0.3 * range_b)
    hist_xlim_b = (min_b - 0.05 * range_b, max_b + 0.05 * range_b)
    counts_b_lb, _ = np.histogram(lb_data_b, bins=25)
    counts_b_tm, _ = np.histogram(tm_data_b, bins=25)
    max_count_b = max(counts_b_lb.max(), counts_b_tm.max())
    hist_ylim_b = (0, max_count_b * 1.1)

    # --- 3. 创建图形和子图布局 ---
    fig = plt.figure(figsize=(12, 14))
    gs = gridspec.GridSpec(3, 2, figure=fig, hspace=0.4, wspace=0.3, height_ratios=[2, 1, 1])
    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    ax3 = fig.add_subplot(gs[1, 0])
    ax4 = fig.add_subplot(gs[1, 1])
    ax5 = fig.add_subplot(gs[2, 0])
    ax6 = fig.add_subplot(gs[2, 1])

    # --- 4. 绘制所有子图 ---
    # (这部分代码没有变化)
    # 子图 (a) 和 (b) ... (省略未改动部分以保持简洁)
    # 子图 (a)
    ax1.scatter(range(len(lb_data_a)), lb_data_a, facecolors='none', edgecolors='royalblue', marker='o', label='LB')
    ax1.scatter(range(len(tm_data_a)), tm_data_a, facecolors='none', edgecolors='orchid', marker='^', label='TM')
    ax1.axhline(y=lb_mean_a, color='royalblue', linestyle='-')
    ax1.axhline(y=tm_mean_a, color='orchid', linestyle='--')
    ax1.fill_between(range(len(lb_data_a)), lb_ci_a[0], lb_ci_a[1], color='royalblue', alpha=0.2)
    ax1.fill_between(range(len(lb_data_a)), tm_ci_a[0], tm_ci_a[1], color='orchid', alpha=0.2)
    ax1.set_title('(a)', loc='left', fontsize=16)
    ax1.set_xlabel('Image Index', fontsize=14)
    ax1.set_ylabel(ylabel_a, fontsize=14)
    ax1.text(0.05, 0.95, f'LB: Avg={lb_mean_a:.2f}, STD={np.std(lb_data_a):.2f}\n    95% CI: [{lb_ci_a[0]:.2f}, {lb_ci_a[1]:.2f}]\nTM: Avg={tm_mean_a:.2f}, STD={np.std(tm_data_a):.2f}\n    95% CI: [{tm_ci_a[0]:.2f}, {tm_ci_a[1]:.2f}]',
             transform=ax1.transAxes, fontsize=12, verticalalignment='top')
    ax1.tick_params(axis='both', which='major', labelsize=12)
    ax1.legend(loc='upper right', fontsize=12)

    # 子图 (b)
    ax2.scatter(range(len(lb_data_b)), lb_data_b, facecolors='none', edgecolors='royalblue', marker='o', label='LB')
    ax2.scatter(range(len(tm_data_b)), tm_data_b, facecolors='none', edgecolors='orchid', marker='^', label='TM')
    ax2.axhline(y=lb_mean_b, color='royalblue', linestyle='-')
    ax2.axhline(y=tm_mean_b, color='orchid', linestyle='--')
    ax2.fill_between(range(len(lb_data_b)), lb_ci_b[0], lb_ci_b[1], color='royalblue', alpha=0.2)
    ax2.fill_between(range(len(lb_data_b)), tm_ci_b[0], tm_ci_b[1], color='orchid', alpha=0.2)
    ax2.set_title('(b)', loc='left', fontsize=16)
    ax2.set_xlabel('Image Index', fontsize=14)
    ax2.set_ylabel(ylabel_b, fontsize=14)
    ax2.text(0.05, 0.95, f'LB: Avg={lb_mean_b:.2f}, STD={np.std(lb_data_b):.2f}\n    95% CI: [{lb_ci_b[0]:.2f}, {lb_ci_b[1]:.2f}]\nTM: Avg={tm_mean_b:.2f}, STD={np.std(tm_data_b):.2f}\n    95% CI: [{tm_ci_b[0]:.2f}, {tm_ci_b[1]:.2f}]',
             transform=ax2.transAxes, fontsize=12, verticalalignment='top')
    ax2.tick_params(axis='both', which='major', labelsize=12)
    ax2.legend(loc='upper right', fontsize=12)

    # --- 新增改动在这里 ---
    # 为 (c) 和 (e) 创建共用的bins
    # 我们使用之前为x轴范围计算好的 hist_xlim_a 来确保bins覆盖所有数据
    common_bins_a = np.linspace(hist_xlim_a[0], hist_xlim_a[1], 20 + 1) # 20个柱子需要21个边界

    # 为 (d) 和 (f) 创建共用的bins
    common_bins_b = np.linspace(hist_xlim_b[0], hist_xlim_b[1], 25 + 1) # 25个柱子需要26个边界
    
    # 直方图
    # --- 在这里应用 common_bins_a ---
    ax3.hist(lb_data_a, bins=common_bins_a, color='royalblue', alpha=0.7, label='LB', edgecolor='black', linewidth=1.2)
    ax3.set_title('(c)', loc='left', fontsize=16)
    ax3.set_ylabel('Image number', fontsize=14)
    ax3.legend(fontsize=12)
    
    # --- 在这里应用 common_bins_a ---
    ax5.hist(tm_data_a, bins=common_bins_a, color='orchid', alpha=0.7, label='TM', edgecolor='black', linewidth=1.2)
    ax5.set_title('(e)', loc='left', fontsize=16)
    ax5.set_xlabel(ylabel_a.lower(), fontsize=14)
    ax5.set_ylabel('Image number', fontsize=14)
    ax5.legend(fontsize=12)
    
    # --- 在这里应用 common_bins_b ---
    ax4.hist(lb_data_b, bins=common_bins_b, color='royalblue', alpha=0.7, label='LB', edgecolor='black', linewidth=1.2)
    ax4.set_title('(d)', loc='left', fontsize=16)
    ax4.set_ylabel('Image number', fontsize=14)
    ax4.legend(fontsize=12)

    # --- 在这里应用 common_bins_b ---
    ax6.hist(tm_data_b, bins=common_bins_b, color='orchid', alpha=0.7, label='TM', edgecolor='black', linewidth=1.2)
    ax6.set_title('(f)', loc='left', fontsize=16)
    ax6.set_xlabel(ylabel_b, fontsize=14)
    ax6.set_ylabel('Image number', fontsize=14)
    ax6.legend(fontsize=12)

    # --- 5. 应用统一且动态的坐标轴范围 ---
    # (这部分代码没有变化)
    ax1.set_xlim(0, len(lb_data_a) - 1)
    ax2.set_xlim(0, len(lb_data_b) - 1)
    ax1.set_ylim(scatter_ylim_a)
    ax2.set_ylim(scatter_ylim_b)
    ax3.set_xlim(hist_xlim_a)
    ax5.set_xlim(hist_xlim_a)
    ax3.set_ylim(hist_ylim_a)
    ax5.set_ylim(hist_ylim_a)
    ax4.set_xlim(hist_xlim_b)
    ax6.set_xlim(hist_xlim_b)
    ax4.set_ylim(hist_ylim_b)
    ax6.set_ylim(hist_ylim_b)
    
    # --- 6. 显示或保存图形 ---
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"图形已保存至: {save_path}")
        plt.close(fig)
    else:
        plt.show()

# %%
plot_comparison_figure(
        lb_data_a=bain_area_percentage_list,
        tm_data_a=mar_area_percentage_list,
        lb_data_b=bainite_k_list,
        tm_data_b=martensite_k_list,
        ylabel_a='Carbide Percentage',
        ylabel_b='Orientation (k)'
    )

# %%
data_to_write = {
    'Carbide percentage_bain: ': bain_area_percentage_list,
    'Carbide percentage Mar: ': mar_area_percentage_list,
    'Carbide orientation Bain: ': bainite_k_list,
    'Carbide orientation Mar: ': martensite_k_list
} 

with open(f'Percentage_Orientation_v2_{model_name}.csv', "w", newline='') as csv_file:
    writer = csv.writer(csv_file)
    
    # This part was already correct
    for header, data_list in data_to_write.items():
        writer.writerow([header])
        writer.writerow(data_list)
        
    # Add a blank row for spacing
    writer.writerow([]) 
    
    # --- T-test for Carbide Percentages ---
    t_stat, p_val = stats.ttest_ind(bain_area_percentage_list, mar_area_percentage_list)

    writer.writerow([f"t-statistic for carbide percentages: {t_stat}"]) 
    writer.writerow([f"p-value for carbide percentages: {p_val}"])     

    if p_val < 0.05:
        writer.writerow(["Conclusion: Reject the null hypothesis. The difference between the group means is statistically significant."]) 
    else:
        writer.writerow(["Conclusion: Fail to reject the null hypothesis. There is no statistically significant difference between the groups."]) 
    
    # Add a blank row for spacing
    writer.writerow([]) 
        
    # --- T-test for Carbide Orientations ---
    t_stat, p_val = stats.ttest_ind(bainite_k_list, martensite_k_list)

    # Wrap each string in a list []
    writer.writerow([f"t-statistic for carbide orientations: {t_stat}"]) 
    writer.writerow([f"p-value for carbide orientations: {p_val}"])    

    if p_val < 0.05:
        writer.writerow(["Conclusion: Reject the null hypothesis. The difference between the group means is statistically significant."]) 
    else:
        writer.writerow(["Conclusion: Fail to reject the null hypothesis. There is no statistically significant difference between the groups."]) 

print(f"File 'Percentage_Orientation_v2_{model_name}.csv' has been written successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 data_to_write = {
# ----> 2     'Carbide percentage_bain: ': bain_area_percentage_list,
#       3     'Carbide percentage Mar: ': mar_area_percentage_list,
#       4     'Carbide orientation Bain: ': bainite_k_list,
#       5     'Carbide orientation Mar: ': martensite_k_list
#       6 }
#       8 with open(f'Percentage_Orientation_v2_{model_name}.csv', "w", newline='') as csv_file:
#       9     writer = csv.writer(csv_file)
#
# NameError: name 'bain_area_percentage_list' is not defined
