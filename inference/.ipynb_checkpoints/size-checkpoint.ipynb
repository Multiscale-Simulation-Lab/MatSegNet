# %%
import pandas as pd
import os
from pathlib import Path  
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import cv2
import numpy as np
import shutil
from skimage import measure

# %%
model_name="Segformer"

# %%
HOME_DIR = Path("C:/Users/xiaoh/Desktop/3rd-Paper/Segmentation_Pipeline/outputs/Segformer_qualitative_results")
PREDICTIONS_DIR = Path(os.path.join(HOME_DIR,"Predictions") )
INPUT_MARTENSITE_PATH = Path(os.path.join(PREDICTIONS_DIR,"martensite")  )
INPUT_BAINITE_PATH = Path(os.path.join(PREDICTIONS_DIR,"bainite") )

TEXT_FILE_PATH = Path("C:/Users/xiaoh/Desktop/3rd-Paper/Segmentation_Pipeline/data/SEM_images")
OUTPUT_MERGED_IMAGES_PATH = Path(os.path.join(PREDICTIONS_DIR,"big_merged_images"))
OUTPUT_FIGURE_PATH = HOME_DIR

# %%
STEEL_TYPE_PATHS = {
    'N5325BAINITE': INPUT_BAINITE_PATH,
    'N5440MARTENSITE': INPUT_MARTENSITE_PATH
}

TILE_HEIGHT = 512
TILE_WIDTH = 512

LOWER_BOUND_COLOR = np.array([210, 210, 0])
UPPER_BOUND_COLOR = np.array([255, 255, 80])

# --- 尺寸计算参数 ---
# 像素到物理面积的转换系数: (nm/pixel)^2 = (61.8 / magnification)^2
# 将其定义为常量，增加可读性
NM_PER_PIXEL_BASE_MAG = 61.8 
# 过滤掉面积过小的噪点（单位：像素）
MIN_PRECIPITATE_PIXEL_AREA = 30
# 需要从尺寸分析中排除的特定放大倍数
EXCLUDED_MAGNIFICATION = 2500

# --- 绘图参数 ---
PLOT_FONT = "Times New Roman"
FIGURE_DPI = 600

# %%
def load_images_from_folder(folder_path):
    images = {}
    image_extensions = ['.png', '.jpg', '.jpeg', '.gif', '.svg']
    for file_path in folder_path.iterdir():
        if file_path.suffix.lower() in image_extensions:
            img = cv2.imread(str(file_path))
            if img is not None:
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                images[file_path.name] = img_rgb
    return images

# %%
def get_image_size_from_df(name, df) :
    image_size = {}
    for _, row in df.iterrows():
        key = f"{name}_{row.iloc[3]}"
        size = (row.iloc[11], row.iloc[12])
        image_size[key] = size
    return image_size

# %%
def resize_images(images, size_map):
    resized_images = {}
    for name, img in images.items():
        if name in size_map:
            target_height, target_width = size_map[name]
            resized_images[name] = cv2.resize(img, (target_width, target_height))
    return resized_images

# %%
def get_remainder_dimension(total_dim, tile_dim):
    remainder = total_dim % tile_dim
    return remainder if remainder != 0 else tile_dim

# %%
def merge_tiles_to_image(tiles, image_size_map, tile_h, tile_w):
    stitched_images = {}
    for base_name, (full_h, full_w) in image_size_map.items():
        print(f"Stitching image: {base_name}, target size: {full_h}x{full_w}")
        num_channels = 3 
        first_tile = next(iter(tiles.values()), None)
        if first_tile is not None:
            if first_tile.ndim == 3:
                num_channels = first_tile.shape[2]
            else: 
                num_channels = 1
        if num_channels > 1:
            stitched_image = np.zeros((full_h, full_w, num_channels), dtype=np.uint8)
        else:
            stitched_image = np.zeros((full_h, full_w), dtype=np.uint8)
        num_y = int(np.ceil(full_h / tile_h))
        num_x = int(np.ceil(full_w / tile_w))
        for j in range(num_y):
            for i in range(num_x):
                tile_name = f"{base_name}_{j}_{i}.png"
                tile = tiles.get(tile_name)
                if tile is None:
                    print(f"Warning: Tile {tile_name} not found! Area will be black.")
                    continue 
                y_start = j * tile_h
                x_start = i * tile_w
            
                h_to_copy = min(tile.shape[0], full_h - y_start)
                w_to_copy = min(tile.shape[1], full_w - x_start)

                stitched_image[y_start : y_start + h_to_copy, x_start : x_start + w_to_copy] = \
                    tile[:h_to_copy, :w_to_copy]

        stitched_images[base_name] = stitched_image
        
    return stitched_images

# %%
def calculate_precipitate_sizes(image_name: str, img: np.ndarray) -> list:
    try:
        magnification = int(image_name.split('X')[0].split('-')[1])
    except (IndexError, ValueError):
        print(f"Warning: Could not parse magnification from '{image_name}'. Skipping size calculation.")
        return []

    if magnification == EXCLUDED_MAGNIFICATION:
        return []

    # 1. 颜色分割来创建掩码
    mask = cv2.inRange(img, LOWER_BOUND_COLOR, UPPER_BOUND_COLOR)
    
    # 2. 标记和测量独立的区域
    labels = measure.label(mask)
    props = measure.regionprops(labels)
    
    pixel_areas = [prop.area for prop in props if prop.area >= MIN_PRECIPITATE_PIXEL_AREA]
    
    # 3. 将像素面积转换为物理面积 (nm^2)
    conversion_factor = (NM_PER_PIXEL_BASE_MAG / magnification)**2
    physical_areas = [area * conversion_factor * 10**6 for area in pixel_areas]
    
    return physical_areas

# %%
def plot_histogram(ax, data, bins, use_percentage=False, labels=None):
    weights = [np.ones(len(d)) / len(d) for d in data] if use_percentage else None
    
    ax.hist(data, bins=bins, weights=weights, label=labels)
    
    if use_percentage:
        ax.yaxis.set_major_formatter(PercentFormatter(1))
        ax.set_ylabel('Percentage of Precipitates', fontsize=16)
    else:
        ax.set_ylabel('Number of Carbide Precipitates', fontsize=16)
        
    ax.set_xlabel('Precipitate Area (nm²)', fontsize=16)
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

# %%
def get_display_names(steel_keys: list) -> list:
    name_map = {
        'N5325BAINITE': 'N5 325 Lower Bainite',
        'N5440MARTENSITE': 'N5 440 Tempered Martensite'
    }
    return [name_map.get(key, 'UNKNOWN') for key in steel_keys]

# %%
dataframe_dict = {}
original_dataframe = {}
for file_path in TEXT_FILE_PATH.glob('*_resized.txt'):
    df = pd.read_csv(file_path, header=None, delimiter=r"\s+")
    name = file_path.name.split('_')[0]
    dataframe_dict[name] = get_image_size_from_df(name, df)

# %%
dataframe_dict
# Out:
# {'42CrMo4BAINITE': {'42CrMo4BAINITE_0.3-2500X_005': (7072, 8192),
#   '42CrMo4BAINITE_0.3-2500X_006': (7072, 8192),
#   '42CrMo4BAINITE_0.3-5000X_007': (3536, 4096),
#   '42CrMo4BAINITE_0.35-5000X_011': (3536, 4096),
#   '42CrMo4BAINITE_0.35-6000X_002': (2946, 3413),
#   '42CrMo4BAINITE_0.35-6000X_008': (2946, 3413),
#   '42CrMo4BAINITE_0.35-6000X_03': (2946, 3413),
#   '42CrMo4BAINITE_0.4-6000X': (2946, 3413),
#   '42CrMo4BAINITE_0.43-10000X_003': (1768, 2048),
#   '42CrMo4BAINITE_0.43-10000X_014': (1768, 2048),
#   '42CrMo4BAINITE_0.43-15000X_013': (1178, 1365),
#   '42CrMo4BAINITE_0.45-15000X_004': (1178, 1365),
#   '42CrMo4BAINITE_0.45-15000X_012': (1178, 1365),
#   '42CrMo4BAINITE_0.48-10000X_010': (1768, 2048),
#   '42CrMo4BAINITE_0.5-10000X_009': (1768, 2048)},
#  'N5325BAINITE': {'N5325BAINITE_0.2-2500X_004': (7072, 8192),
#   'N5325BAINITE_0.35-5000X_005': (3536, 4096),
#   'N5325BAINITE_0.38-6000X_003': (2946, 3413),
#   'N5325BAINITE_0.38-6000X_008': (2946, 3413),
#   'N5325BAINITE_0.43-10000X_002': (1768, 2048),
#   'N5325BAINITE_0.43-10000X_007': (1768, 2048),
#   'N5325BAINITE_0.43-15000X_001': (1178, 1365),
#   'N5325BAINITE_0.43-15000X_006': (1178, 1365),
#   'N5325BAINITE_0.45-20000X': (884, 1024),
#   'N5325BAINITE_0.5-10000X_010': (1768, 2048),
#   'N5325BAINITE_0.5-15000X_009': (1178, 1365),
#   'N5325BAINITE_0.5-6000X_011': (2946, 3413)},
#  'N5440MARTENSITE': {'N5440MARTENSITE_0.43-6000X_015': (2946, 3413),
#   'N5440MARTENSITE_0.43-6000X_021': (2946, 3413),
#   'N5440MARTENSITE_0.45-10000X_017': (1768, 2048),
#   'N5440MARTENSITE_0.45-5000X_022': (3536, 4096),
#   'N5440MARTENSITE_0.48-10000X_014': (1768, 2048),
#   'N5440MARTENSITE_0.48-10000X_020': (1768, 2048),
#   'N5440MARTENSITE_0.48-15000X_013': (1178, 1365),
#   'N5440MARTENSITE_0.48-20000X_012': (884, 1024),
#   'N5440MARTENSITE_0.48-6000X_016': (2946, 3413),
#   'N5440MARTENSITE_0.5-15000X_018': (1178, 1365),
#   'N5440MARTENSITE_0.5-15000X_019': (1178, 1365)}}

# %%
for file_path in TEXT_FILE_PATH.glob('*_without_resize.txt'):
    df = pd.read_csv(file_path, header=None, delimiter=r"\s+")
    name = "".join(file_path.name.split('_')[0])
    print(name)
    original_dataframe[name] = get_image_size_from_df(name, df)
# Out:
# 42CrMo4BAINITE
# N5325BAINITE
# N5440MARTENSITE

# %%
original_dataframe
# Out:
# {'42CrMo4BAINITE': {'42CrMo4BAINITE_0.3-2500X_005': (1768, 2048),
#   '42CrMo4BAINITE_0.3-2500X_006': (1768, 2048),
#   '42CrMo4BAINITE_0.3-5000X_007': (1768, 2048),
#   '42CrMo4BAINITE_0.35-5000X_011': (1768, 2048),
#   '42CrMo4BAINITE_0.35-6000X_002': (1768, 2048),
#   '42CrMo4BAINITE_0.35-6000X_008': (1768, 2048),
#   '42CrMo4BAINITE_0.35-6000X_03': (1768, 2048),
#   '42CrMo4BAINITE_0.4-6000X': (1768, 2048),
#   '42CrMo4BAINITE_0.43-10000X_003': (1768, 2048),
#   '42CrMo4BAINITE_0.43-10000X_014': (1768, 2048),
#   '42CrMo4BAINITE_0.43-15000X_013': (1768, 2048),
#   '42CrMo4BAINITE_0.45-15000X_004': (1768, 2048),
#   '42CrMo4BAINITE_0.45-15000X_012': (1768, 2048),
#   '42CrMo4BAINITE_0.48-10000X_010': (1768, 2048),
#   '42CrMo4BAINITE_0.5-10000X_009': (1768, 2048)},
#  'N5325BAINITE': {'N5325BAINITE_0.2-2500X_004': (1768, 2048),
#   'N5325BAINITE_0.35-5000X_005': (1768, 2048),
#   'N5325BAINITE_0.38-6000X_003': (1768, 2048),
#   'N5325BAINITE_0.38-6000X_008': (1768, 2048),
#   'N5325BAINITE_0.43-10000X_002': (1768, 2048),
#   'N5325BAINITE_0.43-10000X_007': (1768, 2048),
#   'N5325BAINITE_0.43-15000X_001': (1768, 2048),
#   'N5325BAINITE_0.43-15000X_006': (1768, 2048),
#   'N5325BAINITE_0.45-20000X': (1768, 2048),
#   'N5325BAINITE_0.5-10000X_010': (1768, 2048),
#   'N5325BAINITE_0.5-15000X_009': (1768, 2048),
#   'N5325BAINITE_0.5-6000X_011': (1768, 2048)},
#  'N5440MARTENSITE': {'N5440MARTENSITE_0.43-6000X_015': (1768, 2048),
#   'N5440MARTENSITE_0.43-6000X_021': (1768, 2048),
#   'N5440MARTENSITE_0.45-10000X_017': (1768, 2048),
#   'N5440MARTENSITE_0.45-5000X_022': (1768, 2048),
#   'N5440MARTENSITE_0.48-10000X_014': (1768, 2048),
#   'N5440MARTENSITE_0.48-10000X_020': (1768, 2048),
#   'N5440MARTENSITE_0.48-15000X_013': (1768, 2048),
#   'N5440MARTENSITE_0.48-20000X_012': (1768, 2048),
#   'N5440MARTENSITE_0.48-6000X_016': (1768, 2048),
#   'N5440MARTENSITE_0.5-15000X_018': (1768, 2048),
#   'N5440MARTENSITE_0.5-15000X_019': (1768, 2048)}}

# %%
all_resized_images = {}
for steel_name, folder_path in STEEL_TYPE_PATHS.items():
    print(f"\nProcessing steel type: {steel_name}")
    print(f"\folder path type: {folder_path}")
    image_tiles = load_images_from_folder(folder_path)
    merged_images = merge_tiles_to_image(
        image_tiles, dataframe_dict.get(steel_name, {}), TILE_HEIGHT, TILE_WIDTH
    )
    all_resized_images[steel_name] = resize_images(
        merged_images, original_dataframe.get(steel_name, {})
    )
# Out:
# Processing steel type: N5325BAINITE
# older path type: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\Segformer_qualitative_results\Predictions\bainite
# Stitching image: N5325BAINITE_0.2-2500X_004, target size: 7072x8192
# Stitching image: N5325BAINITE_0.35-5000X_005, target size: 3536x4096
# Stitching image: N5325BAINITE_0.38-6000X_003, target size: 2946x3413
# Stitching image: N5325BAINITE_0.38-6000X_008, target size: 2946x3413
# Stitching image: N5325BAINITE_0.43-10000X_002, target size: 1768x2048
# Stitching image: N5325BAINITE_0.43-10000X_007, target size: 1768x2048
# Stitching image: N5325BAINITE_0.43-15000X_001, target size: 1178x1365
# Stitching image: N5325BAINITE_0.43-15000X_006, target size: 1178x1365
# Stitching image: N5325BAINITE_0.45-20000X, target size: 884x1024
# Stitching image: N5325BAINITE_0.5-10000X_010, target size: 1768x2048
# Stitching image: N5325BAINITE_0.5-15000X_009, target size: 1178x1365
# Stitching image: N5325BAINITE_0.5-6000X_011, target size: 2946x3413
#
# Processing steel type: N5440MARTENSITE
# older path type: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\Segformer_qualitative_results\Predictions\martensite
# Stitching image: N5440MARTENSITE_0.43-6000X_015, target size: 2946x3413
# Stitching image: N5440MARTENSITE_0.43-6000X_021, target size: 2946x3413
# Stitching image: N5440MARTENSITE_0.45-10000X_017, target size: 1768x2048
# Stitching image: N5440MARTENSITE_0.45-5000X_022, target size: 3536x4096
# Stitching image: N5440MARTENSITE_0.48-10000X_014, target size: 1768x2048
# Stitching image: N5440MARTENSITE_0.48-10000X_020, target size: 1768x2048
# Stitching image: N5440MARTENSITE_0.48-15000X_013, target size: 1178x1365
# Stitching image: N5440MARTENSITE_0.48-20000X_012, target size: 884x1024
# Stitching image: N5440MARTENSITE_0.48-6000X_016, target size: 2946x3413
# Stitching image: N5440MARTENSITE_0.5-15000X_018, target size: 1178x1365
# Stitching image: N5440MARTENSITE_0.5-15000X_019, target size: 1178x1365

# %%
# --- 3. 保存处理后的大图 ---
if OUTPUT_MERGED_IMAGES_PATH.exists():
    shutil.rmtree(OUTPUT_MERGED_IMAGES_PATH)
OUTPUT_MERGED_IMAGES_PATH.mkdir(parents=True)

for steel_name, images in all_resized_images.items():
    steel_output_dir = OUTPUT_MERGED_IMAGES_PATH / steel_name
    steel_output_dir.mkdir()
    for image_name, img_data in images.items():
        # 将图像从RGB转回BGR以供cv2.imwrite保存
        img_bgr = cv2.cvtColor(img_data, cv2.COLOR_RGB2BGR)
        save_path = steel_output_dir / f"{image_name}.png"
        cv2.imwrite(str(save_path), img_bgr)

# --- 4. 计算并合并析出物尺寸 ---
merged_size_list = {}
for steel_name, images in all_resized_images.items():
    all_sizes = []
    for image_name, img_data in images.items():
        print(f"Analyzing precipitates in: {image_name}")
        sizes = calculate_precipitate_sizes(image_name, img_data)
        all_sizes.extend(sizes)
    merged_size_list[steel_name] = np.array(all_sizes)

# --- 5. 数据可视化 ---
plt.rcParams["font.family"] = PLOT_FONT
plt.rcParams["axes.linewidth"] = 1.0

display_labels = get_display_names(list(merged_size_list.keys()))
size_data = list(merged_size_list.values())

# 绘制百分比图
fig1, ax1 = plt.subplots(figsize=(15, 8))
bins1 = np.linspace(0, 80000, 60)
plot_histogram(ax1, size_data, bins1, use_percentage=True, labels=display_labels)
legend=ax1.legend(loc='upper right', prop={'size': 13})
legend.set_zorder(100)
# 内嵌图
ax1_inset = fig1.add_axes([0.35, 0.3, 0.5, 0.5])
bins1_inset = np.linspace(20000, 80000, 60)
plot_histogram(ax1_inset, size_data, bins1_inset, use_percentage=True)
fig1.savefig(OUTPUT_FIGURE_PATH / "size_distribution_percentage.png", dpi=FIGURE_DPI)

# 绘制数量图
fig2, ax2 = plt.subplots(figsize=(15, 8))
bins2 = np.linspace(0, 80000, 60)
plot_histogram(ax2, size_data, bins2, use_percentage=False, labels=display_labels)
legend=ax2.legend(loc='upper right', prop={'size': 13})
legend.set_zorder(100)

# 内嵌图
ax2_inset = fig2.add_axes([0.35, 0.3, 0.5, 0.5])
bins2_inset = np.linspace(20000, 80000, 60)
plot_histogram(ax2_inset, size_data, bins2_inset, use_percentage=False)
fig2.savefig(OUTPUT_FIGURE_PATH / "size_distribution_total.png", dpi=FIGURE_DPI)

plt.show()

# --- 6. 将结果保存为CSV文件 ---
output_df_data = []
for steel_name, sizes in merged_size_list.items():
    display_name = get_display_names([steel_name])[0]
    for size in sizes:
        output_df_data.append({'Steel Type': display_name, 'Precipitate Area (nm^2)': size})

output_df = pd.DataFrame(output_df_data)
output_df.to_csv(OUTPUT_FIGURE_PATH / "Size_Distribution.csv", index=False)
print("\nAnalysis complete. Results saved to CSV and PNG files.")
# Out:
# Analyzing precipitates in: N5325BAINITE_0.2-2500X_004
# Analyzing precipitates in: N5325BAINITE_0.35-5000X_005
# Analyzing precipitates in: N5325BAINITE_0.38-6000X_003
# Analyzing precipitates in: N5325BAINITE_0.38-6000X_008
# Analyzing precipitates in: N5325BAINITE_0.43-10000X_002
# Analyzing precipitates in: N5325BAINITE_0.43-10000X_007
# Analyzing precipitates in: N5325BAINITE_0.43-15000X_001
# Analyzing precipitates in: N5325BAINITE_0.43-15000X_006
# Analyzing precipitates in: N5325BAINITE_0.45-20000X
# Analyzing precipitates in: N5325BAINITE_0.5-10000X_010
# Analyzing precipitates in: N5325BAINITE_0.5-15000X_009
# Analyzing precipitates in: N5325BAINITE_0.5-6000X_011
# Analyzing precipitates in: N5440MARTENSITE_0.43-6000X_015
# Analyzing precipitates in: N5440MARTENSITE_0.43-6000X_021
# Analyzing precipitates in: N5440MARTENSITE_0.45-10000X_017
# Analyzing precipitates in: N5440MARTENSITE_0.45-5000X_022
# Analyzing precipitates in: N5440MARTENSITE_0.48-10000X_014
# Analyzing precipitates in: N5440MARTENSITE_0.48-10000X_020
# Analyzing precipitates in: N5440MARTENSITE_0.48-15000X_013
# Analyzing precipitates in: N5440MARTENSITE_0.48-20000X_012
# Analyzing precipitates in: N5440MARTENSITE_0.48-6000X_016
# Analyzing precipitates in: N5440MARTENSITE_0.5-15000X_018
# Analyzing precipitates in: N5440MARTENSITE_0.5-15000X_019
# Analysis complete. Results saved to CSV and PNG files.

# %%
HOME_DIR = Path("C:/Users/xiaoh/Desktop/3rd-Paper/Segmentation_Pipeline/outputs/Segformer_qualitative_results")
PREDICTIONS_DIR = Path(os.path.join(HOME_DIR,"Predictions") )
INPUT_IMAGES_DIR = Path(os.path.join(PREDICTIONS_DIR,"big_merged_images"))
OUTPUT_DIR = Path(os.path.join(PREDICTIONS_DIR,"aspect_ratio_analysis"))



# --- Input Data Configuration ---
STEEL_TYPES = {
    "Lower Bainite": Path(os.path.join(INPUT_IMAGES_DIR,"N5325BAINITE")) ,
    "Tempered Martensite": Path(os.path.join(INPUT_IMAGES_DIR,"N5440MARTENSITE"))
}
# Add any filenames here that you want to exclude from the analysis
FILES_TO_EXCLUDE = [
    'N5325LBITE_0.2-2500X_004.png'
]

# --- Analysis Parameters ---
# Ignore carbides with a pixel area outside this range [MIN, MAX]
CONTOUR_AREA_RANGE = (50, 100000)

# --- Visualization Parameters ---
# Color for the bounding boxes (in BGR format for OpenCV)
BOX_COLOR_BGR = (106, 106, 255)  # A shade of red
FONT_FAMILY = "Times New Roman"
FIGURE_DPI = 300

# %%
def analyze_carbide_shapes(image_path: Path) -> tuple[list, list]:
    # Load image in BGR format
    img_bgr = cv2.imread(str(image_path))
    if img_bgr is None:
        print(f"Warning: Could not read image file: {image_path}")
        return [], []

    # Convert to grayscale and then create a binary mask using Otsu's thresholding
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    _, binary_mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours of all distinct shapes in the mask
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)

    aspect_ratios = []
    bounding_boxes = []
    min_area, max_area = CONTOUR_AREA_RANGE

    for contour in contours:
        area = cv2.contourArea(contour)
        if not (min_area < area < max_area):
            continue

        # Get the minimum area bounding rectangle for the contour
        rect = cv2.minAreaRect(contour)
        box_points = cv2.boxPoints(rect)
        box = np.int0(box_points)

        # Get width and height, ensuring they are non-zero
        width, height = rect[1]
        if width <= 0 or height <= 0:
            continue
        
        # Calculate aspect ratio as (longer side / shorter side)
        aspect_ratio = max(width, height) / min(width, height)
        aspect_ratios.append(aspect_ratio)
        bounding_boxes.append(box)

    return aspect_ratios, bounding_boxes

# %%
def create_highlighted_image(original_image_path: Path, boxes: list) -> np.ndarray:
    """
    Draws bounding boxes on an image for visualization.

    Args:
        original_image_path (Path): Path to the original image.
        boxes (list): A list of bounding box coordinates to draw.

    Returns:
        np.ndarray: A new image (in BGR format) with the highlights.
    """
    img_bgr = cv2.imread(str(original_image_path))
    cv2.drawContours(img_bgr, boxes, -1, BOX_COLOR_BGR, 2)
    return img_bgr

# %%
def process_steel_type(steel_name: str, image_folder: Path) -> list:
    """
    Orchestrates the analysis for all images of a specific steel type.

    Args:
        steel_name (str): The display name of the steel (e.g., "Lower Bainite").
        image_folder (Path): The folder containing the images.

    Returns:
        list: A flattened list of all aspect ratios found for this steel type.
    """
    print(f"\nProcessing steel type: {steel_name}...")
    image_folder=Path(image_folder)
    all_ratios = []

    # Prepare the output directory for this steel type's highlighted images
    output_image_dir = Path(os.path.join(OUTPUT_DIR,steel_name.replace(" ", "_")))

    output_image_dir.mkdir(parents=True, exist_ok=True)

    image_paths = [p for p in image_folder.glob("*.png") if p.name not in FILES_TO_EXCLUDE]

    for image_path in image_paths:
        ratios, boxes = analyze_carbide_shapes(image_path)
        
        if ratios:
            all_ratios.extend(ratios)
            
            # Create and save the highlighted image for visual verification
            highlighted_img = create_highlighted_image(image_path, boxes)
            save_path = output_image_dir / f"{image_path.stem}_highlighted.png"
            cv2.imwrite(str(save_path), highlighted_img)


    return all_ratios

# %%
OUTPUT_DIR
# Out:
# WindowsPath('C:/Users/xiaoh/Desktop/3rd-Paper/Segmentation_Pipeline/outputs/Segformer_qualitative_results/Predictions/aspect_ratio_analysis')

# %%
if OUTPUT_DIR.exists():
    shutil.rmtree(OUTPUT_DIR)
OUTPUT_DIR.mkdir(parents=True)

# %%
STEEL_TYPES
# Out:
# {'Lower Bainite': WindowsPath('C:/Users/xiaoh/Desktop/3rd-Paper/Segmentation_Pipeline/outputs/Segformer_qualitative_results/Predictions/big_merged_images/N5325BAINITE'),
#  'Tempered Martensite': WindowsPath('C:/Users/xiaoh/Desktop/3rd-Paper/Segmentation_Pipeline/outputs/Segformer_qualitative_results/Predictions/big_merged_images/N5440MARTENSITE')}

# %%
results_data = {}
for name, path in STEEL_TYPES.items():
    results_data[name] = process_steel_type(name, path)
# Out:
# Processing steel type: Lower Bainite...
# C:\Users\xiaoh\AppData\Local\Temp\ipykernel_13364\4159208969.py:27: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   box = np.int0(box_points)
# Processing steel type: Tempered Martensite...

# %%
results_data
# Out:
# {'Lower Bainite': [2.08695677524073,
#   1.758620580740284,
#   1.7830189220932033,
#   3.6,
#   3.7142852674642266,
#   2.4583331423043595,
#   1.5454545343082713,
#   1.2222222222222223,
#   1.5652175281262775,
#   1.4666666307013558,
#   1.7142857142857142,
#   3.785714408807465,
#   2.954545283937819,
#   2.5172411735881117,
#   2.7142857142857144,
#   3.428571538669327,
#   2.8313251667350685,
#   3.2,
#   3.940000019637357,
#   2.573770429793348,
#   2.099999838156102,
#   1.700000060691466,
#   3.16666677472898,
#   2.9473679198144564,
#   1.5999998381561016,
#   2.555555622157991,
#   2.145454502356644,
#   4.1666670558746235,
#   1.25,
#   1.9393939885131726,
#   3.3333333333333335,
#   2.5866668197834546,
#   2.2500002950279696,
#   3.8105262183935644,
#   1.8169012401367535,
#   2.2400002050022714,
#   2.0333336194356284,
#   2.046875121282471,
#   2.769230668284946,
#   2.060241033034693,
#   3.581395605718685,
#   2.6666666666666665,
#   1.1612902584512803,
#   2.088607443058068,
#   1.9240505469121543,
#   1.3636363970751864,
#   2.318181845431124,
#   4.437499872398611,
#   2.93750015805068,
#   1.9821428305088933,
#   2.434210627136663,
#   3.581395605718685,
#   2.142857142857143,
#   1.3636363970751864,
#   2.318181845431124,
#   4.437499872398611,
#   3.3571426335065473,
#   3.124999649920381,
#   2.124999972807933,
#   2.277777957881633,
#   2.5357142492216487,
#   3.7142854115165225,
#   4.199999666350256,
#   2.766666780793191,
#   1.0526315316901784,
#   2.857142857142857,
#   1.2017542877479086,
#   1.1538462256703736,
#   2.8499999914036955,
#   2.034482753945184,
#   4.985507356096785,
#   2.437500189053997,
#   2.3239437290485427,
#   2.0679613587816794,
#   2.3225806092158705,
#   1.000000103746095,
#   1.8769230998413369,
#   1.9642857193011478,
#   2.249999831412598,
#   1.230769055198934,
#   2.3846155162998355,
#   2.5000002528811165,
#   2.439393881175333,
#   2.9000000337174767,
#   2.0,
#   1.4000000589815016,
#   1.5833332022097988,
#   1.0588234360761803,
#   3.378048969127746,
#   2.65517268859242,
#   2.0357143491809624,
#   2.054945110310741,
#   3.0833333407377794,
#   2.9924244843342533,
#   1.694915258402207,
#   2.493243500249265,
#   1.0823528484939202,
#   2.0000002997109587,
#   2.7699999117946623,
#   2.5714285714285716,
#   1.9333332569217438,
#   3.277777368227055,
#   2.2878789899001872,
#   4.9621213827120325,
#   1.8333333707972004,
#   2.6,
#   1.8974361169099823,
#   1.0769230609621392,
#   3.9130432169344993,
#   ...]}

# %%
# --- 2. Process Data ---


# --- 3. Visualize Results ---
print("\nGenerating final plot...")
plt.style.use('default')
plt.rcParams['font.family'] = FONT_FAMILY

fig, ax = plt.subplots(figsize=(16, 8))

# Define plot styles for consistency
plot_styles = {
    "Lower Bainite": {'color': 'red', 'marker': '^', 'facecolors': 'none'},
    "Tempered Martensite": {'color': 'blue', 'marker': '>', 'facecolors': 'none'}
}

for name, ratios in results_data.items():
    if not ratios: 
        continue

    # Calculate statistics
    mean_ratio = np.mean(ratios)
    std_ratio = np.std(ratios)

    # Create label text with statistics
    label = f"{name}\n(std: {std_ratio:.2f}, mean: {mean_ratio:.2f})"

    # Create the scatter plot
    ax.scatter(range(len(ratios)), ratios, label=label, **plot_styles.get(name, {}))

# --- 4. Format Plot ---
ax.set_xlabel('Carbide Index', fontsize=20)
ax.set_ylabel('Carbide Aspect Ratio', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15, direction='in', width=2, length=6)
for spine in ax.spines.values():
    spine.set_linewidth(2)

ax.legend(loc='upper right', fontsize=15, frameon=False)

# Save the final plot
plot_save_path = OUTPUT_DIR / "Aspect_Ratio_Comparison.png"
fig.savefig(plot_save_path, dpi=FIGURE_DPI, bbox_inches='tight')
plt.show()
print(f"Final plot saved to: {plot_save_path}")

df_data = []
for name, ratios in results_data.items():
    for ratio in ratios:
        df_data.append({'Steel Type': name, 'Aspect Ratio': ratio})

df = pd.DataFrame(df_data)
csv_save_path = OUTPUT_DIR / "Aspect_Ratio_Data.csv"
df.to_csv(csv_save_path, index=False)
print(f"Raw data saved to: {csv_save_path}")
# Out:
# Generating final plot...
# Final plot saved to: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\Segformer_qualitative_results\Predictions\aspect_ratio_analysis\Aspect_Ratio_Comparison.png
# Raw data saved to: C:\Users\xiaoh\Desktop\3rd-Paper\Segmentation_Pipeline\outputs\Segformer_qualitative_results\Predictions\aspect_ratio_analysis\Aspect_Ratio_Data.csv

# %%
font_size=16
# ======= 作图 =======
# 使用 constrained_layout=True 自动调整布局，防止标签重叠
fig, axes = plt.subplots(2, 2, figsize=(10, 6), constrained_layout=True)

# 定义文本标签的样式
text_props = {'ha': 'center', 'va': 'center', 'fontsize': 14}

# (a) LB 散点图
axes[0, 0].scatter(np.arange(len(results_data['Lower Bainite'])), results_data['Lower Bainite'], 
                   marker='^', s=20, facecolors='none', edgecolors='royalblue',alpha=0.7)
axes[0, 0].set_ylabel("Carbide Aspect Ratio",fontsize=font_size)
# --- 修改点：使用 ax.text() 代替 ax.set_title() ---
# (0.05, 0.95) 代表从左边5%和上边5%的位置，ha/va设置对齐方式
axes[0, 0].text(0.05, 0.95, '(a) LB', transform=axes[0, 0].transAxes, 
                fontsize=14, va='top', ha='left')


# (b) TM 散点图
axes[1, 0].scatter(np.arange(len(results_data['Tempered Martensite'])), results_data['Tempered Martensite'], 
                   marker='o', s=20, facecolors='none', edgecolors='magenta',alpha=0.5)
axes[1, 0].set_xlabel("Carbide Index",fontsize=font_size)
axes[1, 0].set_ylabel("Carbide Aspect Ratio",fontsize=font_size)
# --- 修改点 ---
axes[1, 0].text(0.05, 0.95, '(b) TM', transform=axes[1, 0].transAxes
               ,fontsize=font_size, va='top', ha='left')


# (c) LB 直方图
axes[0, 1].hist(results_data['Lower Bainite'], bins=np.linspace(0, 6, 20), color='royalblue',
                edgecolor='white', hatch='//', alpha=0.7)
axes[0, 1].set_ylabel("Number of carbides",fontsize=font_size)
# --- 修改点：放在右上角 ---
# (0.95, 0.95) 代表从右边5%和上边5%的位置
axes[0, 1].text(0.95, 0.95, '(c) LB', transform=axes[0, 1].transAxes
                ,fontsize=font_size, va='top', ha='right')


# (d) TM 直方图
axes[1, 1].hist(results_data['Tempered Martensite'], bins=np.linspace(0, 6, 20), color='magenta',
                edgecolor='white', hatch='//', alpha=0.5)
axes[1, 1].set_xlabel("Aspect ratio",fontsize=font_size)
axes[1, 1].set_ylabel("Number of carbides",fontsize=font_size)
# --- 修改点 ---
axes[1, 1].text(0.95, 0.95, '(d) TM', transform=axes[1, 1].transAxes
                ,fontsize=font_size, va='top', ha='right')


# ======= 调整坐标范围，统一风格 =======
for ax in [axes[0, 0], axes[1, 0]]:
    ax.set_ylim(0, 15)  # Y 轴最大值 15

# 为了让直方图更好看，这里不强制设定X轴范围，让它自动适应
for ax in [axes[0, 1], axes[1, 1]]:
    ax.set_xlim(1, 6)   
plt.show()

# %%
results_data
# Out:
# {'Lower Bainite': [2.08695677524073,
#   1.758620580740284,
#   1.7830189220932033,
#   3.6,
#   3.7142852674642266,
#   2.4583331423043595,
#   1.5454545343082713,
#   1.2222222222222223,
#   1.5652175281262775,
#   1.4666666307013558,
#   1.7142857142857142,
#   3.785714408807465,
#   2.954545283937819,
#   2.5172411735881117,
#   2.7142857142857144,
#   3.428571538669327,
#   2.8313251667350685,
#   3.2,
#   3.940000019637357,
#   2.573770429793348,
#   2.099999838156102,
#   1.700000060691466,
#   3.16666677472898,
#   2.9473679198144564,
#   1.5999998381561016,
#   2.555555622157991,
#   2.145454502356644,
#   4.1666670558746235,
#   1.25,
#   1.9393939885131726,
#   3.3333333333333335,
#   2.5866668197834546,
#   2.2500002950279696,
#   3.8105262183935644,
#   1.8169012401367535,
#   2.2400002050022714,
#   2.0333336194356284,
#   2.046875121282471,
#   2.769230668284946,
#   2.060241033034693,
#   3.581395605718685,
#   2.6666666666666665,
#   1.1612902584512803,
#   2.088607443058068,
#   1.9240505469121543,
#   1.3636363970751864,
#   2.318181845431124,
#   4.437499872398611,
#   2.93750015805068,
#   1.9821428305088933,
#   2.434210627136663,
#   3.581395605718685,
#   2.142857142857143,
#   2.4090909486954883,
#   1.0833333146014,
#   4.0,
#   2.647058907531438,
#   3.8181818627669153,
#   1.857142987702898,
#   1.4444444583199505,
#   2.014285657361273,
#   2.7654319166361354,
#   1.5714285714285714,
#   1.5714285714285714,
#   1.8571428571428572,
#   2.812499924840854,
#   2.166666873991181,
#   2.7152315647044527,
#   2.9285714724301197,
#   3.0833338932779535,
#   1.7444445610715162,
#   1.1454544395649464,
#   2.051282109778611,
#   1.454545343082712,
#   1.875,
#   1.7142857693346636,
#   1.625,
#   2.3749999367797208,
#   4.719101901064791,
#   7.280488151717739,
#   2.142857142857143,
#   2.0206185617810624,
#   3.416666829389828,
#   1.6279070474359476,
#   1.1111111111111112,
#   1.454545343082712,
#   1.9375000541450196,
#   3.1558443315696594,
#   1.2727272727272727,
#   3.378048969127746,
#   2.65517268859242,
#   2.0357143491809624,
#   2.054945110310741,
#   3.0833333407377794,
#   2.9924244843342533,
#   1.694915258402207,
#   2.493243500249265,
#   1.0823528484939202,
#   2.0000002997109587,
#   2.7699999117946623,
#   2.5714285714285716,
#   1.9333332569217438,
#   3.277777368227055,
#   2.2878789899001872,
#   4.9621213827120325,
#   1.8333333707972004,
#   2.6,
#   1.8974361169099823,
#   1.0769230609621392,
#   3.9130432169344993,
#   ...]}

# %%
import csv
from scipy import stats

with open(f'Size_and_Aspect_ratio_{model_name}.csv', "w", newline='') as csv_file:
    writer = csv.writer(csv_file)
    
    # This part was already correct
    for header, data_list in results_data.items():
        writer.writerow([header])
        writer.writerow(data_list)
        
    # Add a blank row for spacing
    writer.writerow([]) 
    
    # --- T-test for Carbide Percentages ---
    t_stat, p_val = stats.ttest_ind(results_data['Lower Bainite'], results_data['Lower Bainite'])

    writer.writerow([f"t-statistic for carbide percentages: {t_stat}"]) 
    writer.writerow([f"p-value for carbide percentages: {p_val}"])     

    if p_val < 0.05:
        writer.writerow(["Conclusion: Reject the null hypothesis. The difference between the group means is statistically significant."]) 
    else:
        writer.writerow(["Conclusion: Fail to reject the null hypothesis. There is no statistically significant difference between the groups."]) 
    
    # Add a blank row for spacing
    writer.writerow([]) 
        
    # --- T-test for Carbide Orientations ---
    t_stat, p_val = stats.ttest_ind(bainite_k_list, martensite_k_list)

    # Wrap each string in a list []
    writer.writerow([f"t-statistic for carbide orientations: {t_stat}"]) 
    writer.writerow([f"p-value for carbide orientations: {p_val}"])    

    if p_val < 0.05:
        writer.writerow(["Conclusion: Reject the null hypothesis. The difference between the group means is statistically significant."]) 
    else:
        writer.writerow(["Conclusion: Fail to reject the null hypothesis. There is no statistically significant difference between the groups."]) 

print(f"File 'Percentage_Orientation_v2_{model_name}.csv' has been written successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 16
#      13 writer.writerow([])
#      15 # --- T-test for Carbide Percentages ---
# ---> 16 t_stat, p_val = stats.ttest_ind(bain_area_percentage_list, mar_area_percentage_list)
#      18 writer.writerow([f"t-statistic for carbide percentages: {t_stat}"])
#      19 writer.writerow([f"p-value for carbide percentages: {p_val}"])
#
# NameError: name 'bain_area_percentage_list' is not defined
